# %%
# %matplotlib inline

import matplotlib
matplotlib.rcParams['figure.figsize'] = (30, 12)
matplotlib.rcParams['font.family'] = 'Hei'

# %%
# remove font cache
# rm -rf $(python -c "import matplotlib; print(matplotlib.get_cachedir())")

# list all available fonts.
from pprint import pprint
from matplotlib.font_manager import FontManager
m = FontManager()
# pprint({f.name:f.fname for f in m.ttflist})

# %%
# pick a font.
matplotlib.rcParams['font.family'] = 'Hei'
# matplotlib.rcParams['font.family'] = 'STHeiti'
# matplotlib.rcParams['font.family'] = 'STFangsong'
# matplotlib.rcParams['font.family'] = 'WenQuanYi Micro Hei'

# %%
from lmk.ticker import Ticker

ticker = Ticker("000001.SS")
# The Grand Stock Market Bubble
ticker.retrieve_history("2020-01-01", "2021-03-08")
ticker.visualize("V,C,CL,LMK,WM,PV", ylimits=(2600,3800))
# Out:
# DEBUG|NetEase.py:163#retrieve_history()# url = 'http://quotes.money.163.com/service/chddata.html?code=0000001&start=20200101&end=20210308&fields=TCLOSE;HIGH;LOW;TOPEN;LCLOSE;CHG;PCHG;VOTURNOVER;VATURNOVER'
# DEBUG|NetEase.py:205#get_quote_today()# url = 'http://api.money.126.net/data/feed/0000001,money.api'
#  INFO|NetEase.py:220#get_quote_today()# get_quote_today(): 000001.SS => price: 3466.51, updown: -35.48, -1.01%

# %%
from lmk.ticker import Ticker

ticker = Ticker("TSLA")
# The Grand Stock Market Bubble
ticker.retrieve_history("2020-06-01", "2021-03-04")
ticker.visualize("V,C,CL,LMK,WM,PV")

# %%
from lmk.ticker import Ticker

ticker = Ticker("600036.SS")
# The Grand Stock Market Bubble
ticker.retrieve_history("2020-06-01", "2021-03-08")
ticker.visualize("V,C,CL,LMK,WM,PV", ylimits=(30,60))
# Out:
# DEBUG|NetEase.py:205#get_quote_today()# url = 'http://api.money.126.net/data/feed/0600036,money.api'
#  INFO|NetEase.py:220#get_quote_today()# get_quote_today(): 600036.SS => price: 50.02, updown: -1.38, -2.68%
